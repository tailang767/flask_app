# %% [markdown]
# メモ
# 1.ローカルでpklファイルpyファイルを書き換える
#
# 2.コマンドプロンプトから下記をうつと、フォルダ内のファイル全て更新される
# 「
# cd ~/Downloads/flask_app
# git add .
# git commit -m "update"
# git push
# 」
#
# 3.renderは自動反映

# %%
#単C999円以下の単語.pkl
#単C1000円以上の単語.pkl
#単C2000円以上の単語.pkl
#プロパー5000円以上の単語.pkl
#プロパー10000円以上のタイトル.pkl

import pickle



data = {'zyanru1': ['kkk', 'sss', 'mmm'], 
        'zyanru2': ['kk', 'ss', 'tt'],
        '語学': ["手紙","文庫","新書","英会話","TOEIC","使える","これ","ない","話せる","ビジネス"],
        '資格': ['看護'],
        '趣味': ['文庫','新書','ブックス','なる','人','写真','ない','本','世界','集','vol','日本','Vol'],
        '人文': ['PHP','新書','術','あなた','人生','文庫','人','岩波','方法','心','自分','生きる','新','ない','なる','講談社'],
        '投資': ['PHP','新書','文庫','日経','リーダー','なぜ','社長','仕事','いる','力','人','会社','ない','こと','営業','術','できる','日本','方','お金','円','世界','ビジネス','時代','な','技術','思考','成功','戦略'],
        '歴史': ['新潮','NHK','漫画','新書','文庫','謎','庫','講談社','昭和','まんが','学習','中','戦国','岩波','旅','新','わかる','中国','東京','江戸','物語','日本','人','時代','大','第','集','版','古代','歴史','改訂','史'],
        '建築': ['文庫','人','家','づくり','年','本','ほん'],
        '学参': ['文庫','新書','済','省','文部','勉強','現代','検定','B','子育て','法','は','科学','教師','新','教科書','人','心','史','方','日本','基礎','英語','式','ない','改訂','教育','子ども','学級','学','科','数学','から','授業','する','小学校','保育','大学'],
        '科学': ['ブルー','バックス','新書','文庫','宇宙','は','新','か','生物','化学','ない','科学','た','方','超','が','なる','学','本','高校','大学','基礎'],
        '医学': ['文庫','新書','系統','講座','分野','生活','学','病気','新','看護','健康','専門','技術','理学','栄養','最新','なる','がん','シリーズ','科学','ない','心','本','精神','法','医学','基礎','病','療法','脳','医療','患者','障害'],
        'スポーツ': ['文庫','新書','フィギュア','スケート','ゴルフ','プロ','サッカー','なる','ない','上達','練習','方','野球','選手','BOOKS','スポーツ','体','シリーズ','BOOK','基本','する','MOOK','山','から','B','ため','トレーニング'],
        'コンピュータ': ['新書','たん','iPad','今','TJMOOK','便利','すぐ','技','仕事','ムック','使える','術','Excel','最新','iPhone','Vol','講座','本','パソコン','わかる','超','Android','MOOK','完全','対応','テクニック','基本','活用','ガイド'],
        'エンタメ': ['書房','キャラ','竹','文庫','新書','号','NEWS','TOKYO','講談社','TV','ガイド','vol','MOOK','人','年','映画','Vol','ブック','日本','シリーズ']
       }

with open("単C999円以下の単語.pkl", "wb") as f:
    pickle.dump(data, f)



data = {'zyanru1': ['kkk', 'sss', 'mmm'], 
        'zyanru2': ['kk', 'ss', 'tt'],
        '語学': ["2026","公立","2025","無料","中級","日本語","DL","音声","小学","年生","！","言語","初級","過去","ドリル","年度","教育","最新","漢字","新装"],
        '資格': ['早稲田','2026','スタンダード','回','日本語','能力','訴訟','民事','技能','出版','答案','登記','解答','研究','次','技士','論文','令和','予備','司法','施工','CD','2025','解説','徹底','語','経営','建築','式','パーフェクト','書士','短','訂','2024','実務','不動産','公式','法','民法','別','！','集','学科','過去','本','答','試験','第','級','管理','問題','行政','検定'],
        '趣味': ['2026','ブランドムック','宝島社','シール','バラエティ','編み','2025','かぎ針','ブティック','レディ','no','図鑑'],
        '人文': ['ドリル','支援','試験','性','語','改訂','的'],
        '投資': ['2025','税務','Q','実務','対応','士','年度','第','中小','合格','試験','改訂','版'],
        '歴史': ['全','県','研究','文化'],
        '建築': ['施工','改訂','作品','画集','級','図鑑'],
        '学参': ['2026','県','都','リアル','形式','春','赤本','感','プリント','知育','ドリル','入学','2025','東京','ワーク','対策','年間','別','過去','思考','中学校','問','試験','スーパー','声','級'],
        '科学': ['2026','2025','士','ドリル','AI','小学','設計','級','種','検定','試験','算数','年版','電気','テキスト','管理','教科書','過去','別冊','第','機械','合格','計算','改訂','学習','新版'],
        '医学': ['2025','2024','動画','付','試験','解説','集','問題','運動','超','号','師'],
        'スポーツ': ['車種','チューニング','ドレスアップ','ハイパーレブ','徹底','mook','NEWS','別','車','ヤエスメディアムック','No','流'],
        'コンピュータ': ['by','Linux','Jw','cad','Server','設計','集','システム','計算','制御','データ','マイコン','公式','AI'],
        'エンタメ': ['演奏','伴奏','リットーミュージック・ムック','ソロ','譜','弾き語り','ヴァイオリン','合唱','改訂','スコア','曲','新版','バンド','ギター','付','楽譜','作品','ピアノ','弾ける','CD','名曲','やさしい','ジャズ','集','練習','付き','はじめて','ベスト','ため']
       }

with open("単C1000円以上の単語.pkl", "wb") as f:
    pickle.dump(data, f)



data = {'zyanru1': ['kkk', 'sss', 'mmm'], 
        'zyanru2': ['kk', 'ss', 'tt'],
        '語学': [],
        '資格': [],
        '趣味': [],
        '人文': [],
        '投資': [],
        '歴史': [],
        '建築': [],
        '学参': [],
        '科学': [],
        '医学': [],
        'スポーツ': [],
        'コンピュータ': [],
        'エンタメ': []
       }

with open("単C2000円以上の単語.pkl", "wb") as f:
    pickle.dump(data, f)



data = {'zyanru1': ['kkk', 'sss', 'mmm'], 
        'zyanru2': ['kk', 'ss', 'tt'],
        '語学': [],
        '資格': [],
        '趣味': [],
        '人文': [],
        '投資': [],
        '歴史': [],
        '建築': [],
        '学参': [],
        '科学': [],
        '医学': [],
        'スポーツ': [],
        'コンピュータ': [],
        'エンタメ': []
       }

with open("プロパー5000円以上の単語.pkl", "wb") as f:
    pickle.dump(data, f)



data = {'zyanru1': ['kkk', 'sss', 'mmm'], 
        'zyanru2': ['kk', 'ss', 'tt'],
        '語学': [],
        '資格': [],
        '趣味': [],
        '人文': [],
        '投資': [],
        '歴史': [],
        '建築': [],
        '学参': [],
        '科学': [],
        '医学': [],
        'スポーツ': [],
        'コンピュータ': [],
        'エンタメ': []
       }

with open("プロパー10000円以上のタイトル.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
import pickle

with open("単C1000円以上の単語.pkl", "rb") as f:
    data = pickle.load(f)

print(data)
# Out:
# {'zyanru1': ['aa', 'ii', 'uu', 'ee', 'oo'], 'zyanru2': ['kk', 'ss', 'tt']}
